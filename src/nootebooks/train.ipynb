# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
from sklearn.model_selection import GridSearchCV
from feature_engine import pipeline

from sklearn.linear_model import LinearRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestRegressor
from xgboost.sklearn import XGBRegressor

# %%
import warnings

warnings.filterwarnings("ignore")

# %%
df_train = pd.read_csv('..//data//processing//train.csv')

df_train
# Out:
#        Unnamed: 0  LND_SQFOOT  TOT_LVG_AREA  SPEC_FEAT_VAL  RAIL_DIST  \
# 0           12356        5000          2726          38983     7770.8
# 1            7612        6000          3067              0    10009.9
# 2            4447       19122          4886          39925     3155.2
# 3           12215        4428          2193              0    13640.9
# 4            4026       20008          4095          31328     5232.9
# ...           ...         ...           ...            ...        ...
# 11140        5191       15620          3306          18129    12028.0
# 11141       13418        6029          3283              0     1755.0
# 11142        5390        8424          1812          19064     5523.0
# 11143         860        7875          1714           1490     5243.4
# 11144        7270        8740          2290          21330     2139.7
#
#        OCEAN_DIST  WATER_DIST  CNTR_DIST  SUBCNTR_DI  HWY_DIST  age  \
# ...

# %%
df_test = pd.read_csv('..//data//processing//test.csv')

df_test
# Out:
#       Unnamed: 0  LND_SQFOOT  TOT_LVG_AREA  SPEC_FEAT_VAL  RAIL_DIST  \
# 0           6442        8250          1920            750    11227.5
# 1           8524        4385          2857           1360    11073.6
# 2          13210        4983          2528           4136      902.6
# 3           2501        5600          1767           3311    14846.0
# 4            168        7740          1700              0     7225.9
# ...          ...         ...           ...            ...        ...
# 2782        4832       35196          3315          24794     8979.4
# 2783        6914        4000          2514           5514     5566.3
# 2784       13607        5366          2412           3715     3768.5
# 2785       12622        6634          3757           2640     8661.6
# 2786       10110        7134          1347           2991    15260.6
#
#       OCEAN_DIST  WATER_DIST  CNTR_DIST  SUBCNTR_DI  HWY_DIST  age  \
# 0        37268.4      7283.3    53965.6     26569.4    9971.9   55
# ...

# %%
df_train.drop(['Unnamed: 0'], axis=1, inplace=True)
df_test.drop(['Unnamed: 0'], axis=1, inplace=True)

df_train
# Out:
#        LND_SQFOOT  TOT_LVG_AREA  SPEC_FEAT_VAL  RAIL_DIST  OCEAN_DIST  \
# 0            5000          2726          38983     7770.8     61942.4
# 1            6000          3067              0    10009.9     33309.8
# 2           19122          4886          39925     3155.2     24140.3
# 3            4428          2193              0    13640.9     58796.7
# 4           20008          4095          31328     5232.9      1506.1
# ...           ...           ...            ...        ...         ...
# 11140       15620          3306          18129    12028.0      5362.5
# 11141        6029          3283              0     1755.0     47589.0
# 11142        8424          1812          19064     5523.0     16485.4
# 11143        7875          1714           1490     5243.4     33513.1
# 11144        8740          2290          21330     2139.7     11625.3
#
#        WATER_DIST  CNTR_DIST  SUBCNTR_DI  HWY_DIST  age  avno60plus  \
# ...

# %%
features = df_train.drop(columns='SALE_PRC').columns.to_list()
target = 'SALE_PRC'

X_train = df_train[features]
y_train = df_train[target]
X_test = df_test[features]
y_test = df_test[target]

# %% [markdown]
# # LINEAR REGRESSION

# %%
linear_regression = LinearRegression()

# %% [markdown]
# ## GridSearchCV

# %%
params = {
    'fit_intercept': [True, False],
}

grid = GridSearchCV(linear_regression,
                    param_grid=params,
                    cv=5,
                    n_jobs=-1)

# %% [markdown]
# ## Pipeline

# %%
pipeline = pipeline.Pipeline([
    ('scaler', StandardScaler()),
    ('grid', grid)
])

# %% [markdown]
# ## Treino

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('grid',
#                  GridSearchCV(cv=5, estimator=LinearRegression(), n_jobs=-1,
#                               param_grid={'fit_intercept': [True, False]}))])

# %%
predict_train = pipeline.predict(X_train)
predict_test = pipeline.predict(X_test)

# %%
train_r2 = metrics.r2_score(y_train, predict_train)
test_r2 = metrics.r2_score(y_test, predict_test)
train_rmse = metrics.root_mean_squared_error(y_train, predict_train)
test_rmse = metrics.root_mean_squared_error(y_test, predict_test)

# %%
print(f'Train R2: {round(train_r2 * 100, 2)}')
print(f'Test R2: {round(test_r2 * 100, 2)}')
print(f'Train RMSE: {round(train_rmse, 2)}')
print(f'Test RMSE: {round(test_rmse, 2)}')
# Out:
# Train R2: 68.67
# Test R2: 68.22
# Train RMSE: 178012.38
# Test RMSE: 176887.85

# %% [markdown]
# # Naive bayes

# %%
nb = GaussianNB()

# %% [markdown]
# ## GridSearchCV

# %%
params = {
    'var_smoothing': [1e-9, 1e-10, 1e-11]
}

grid = GridSearchCV(nb,
                    param_grid=params,
                    cv=5,
                    n_jobs=-1)

# %% [markdown]
# ## Pipeline

# %%
pipeline = pipeline.Pipeline([
    ('scaler', StandardScaler()),
    ('grid', grid)
])

# %% [markdown]
# ## Treino

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('grid',
#                  GridSearchCV(cv=5, estimator=GaussianNB(), n_jobs=-1,
#                               param_grid={'var_smoothing': [1e-09, 1e-10,
#                                                             1e-11]}))])

# %%
predict_train = pipeline.predict(X_train)
predict_test = pipeline.predict(X_test)

# %%
train_r2 = metrics.r2_score(y_train, predict_train)
test_r2 = metrics.r2_score(y_test, predict_test)
train_rmse = metrics.root_mean_squared_error(y_train, predict_train)
test_rmse = metrics.root_mean_squared_error(y_test, predict_test)

# %%
print(f'Train R2: {round(train_r2 * 100, 2)}')
print(f'Test R2: {round(test_r2 * 100, 2)}')
print(f'Train RMSE: {round(train_rmse, 2)}')
print(f'Test RMSE: {round(test_rmse, 2)}')
# Out:
# Train R2: 59.03
# Test R2: 50.74
# Train RMSE: 203575.56
# Test RMSE: 220234.59

# %% [markdown]
# # RandomForestRegressor

# %%
random_forest = RandomForestRegressor(n_estimators=300, max_depth=7, min_samples_split=12, min_samples_leaf=4)

# %% [markdown]
# ## Treino

# %%
random_forest.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=7, min_samples_leaf=4, min_samples_split=12,
#                       n_estimators=300)

# %%
predict_train = random_forest.predict(X_train)
predict_test = random_forest.predict(X_test)

# %%
train_r2 = metrics.r2_score(y_train, predict_train)
test_r2 = metrics.r2_score(y_test, predict_test)
train_rmse = metrics.root_mean_squared_error(y_train, predict_train)
test_rmse = metrics.root_mean_squared_error(y_test, predict_test)

# %%
print(f'Train R2: {round(train_r2 * 100, 2)}')
print(f'Test R2: {round(test_r2 * 100, 2)}')
print(f'Train RMSE: {round(train_rmse, 2)}')
print(f'Test RMSE: {round(test_rmse, 2)}')
# Out:
# Train R2: 90.76
# Test R2: 86.39
# Train RMSE: 96692.52
# Test RMSE: 115766.91
