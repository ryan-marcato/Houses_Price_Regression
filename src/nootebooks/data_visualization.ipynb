# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings

warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("..//data//archive//miami-housing.csv")

df
# Out:
#         LATITUDE  LONGITUDE      PARCELNO  SALE_PRC  LND_SQFOOT  TOT_LVG_AREA  \
# 0      25.891031 -80.160561  622280070620  440000.0        9375          1753
# 1      25.891324 -80.153968  622280100460  349000.0        9375          1715
# 2      25.891334 -80.153740  622280100470  800000.0        9375          2276
# 3      25.891765 -80.152657  622280100530  988000.0       12450          2058
# 4      25.891825 -80.154639  622280100200  755000.0       12800          1684
# ...          ...        ...           ...       ...         ...           ...
# 13927  25.783130 -80.259795  131320040990  275000.0        6780           967
# 13928  25.783585 -80.260354  131320040910  340000.0        7500          1854
# 13929  25.783793 -80.256126  131320040420  287500.0        8460          1271
# 13930  25.784007 -80.257542  131320040330  315000.0        7500          1613
# 13931  25.784387 -80.258901  131320040700  250000.0        8833          1867
#
# ...

# %%
round(df.describe(), 2)
# Out:
#        LATITUDE  LONGITUDE      PARCELNO    SALE_PRC  LND_SQFOOT  \
# count  13932.00   13932.00  1.393200e+04    13932.00    13932.00
# mean      25.73     -80.33  2.356496e+12   399941.93     8620.88
# std        0.14       0.09  1.199290e+12   317214.68     6070.09
# min       25.43     -80.54  1.020008e+11    72000.00     1248.00
# 25%       25.62     -80.40  1.079160e+12   235000.00     5400.00
# 50%       25.73     -80.34  3.040300e+12   310000.00     7500.00
# 75%       25.85     -80.26  3.060170e+12   428000.00     9126.25
# max       25.97     -80.12  3.660170e+12  2650000.00    57064.00
#
#        TOT_LVG_AREA  SPEC_FEAT_VAL  RAIL_DIST  OCEAN_DIST  WATER_DIST  \
# count      13932.00       13932.00   13932.00    13932.00    13932.00
# mean        2058.04        9562.49    8348.55    31690.99    11960.29
# std          813.54       13890.97    6178.03    17595.08    11932.99
# min          854.00           0.00      10.50      236.10        0.00
# ...

# %% [markdown]
# # Graficos

# %% [markdown]
# ## Histograma

# %%
col_plot = ['SALE_PRC', 'age']
fig, axes= plt.subplots(nrows=1, ncols=2)
fig.set_size_inches(22, 8)
fig.suptitle('Histogramas sobre preço e idade', fontsize=24, y=1.03)

coluna = 0

for i in col_plot:
    ax = sns.histplot(x=df[i], kde=True, ax=axes[coluna], color='g')
    ax.set_title(i, fontsize=22, y=1.02)
    
    coluna += 1
    
    plt.tight_layout()

# %% [markdown]
# ## Graficos de barra

# %%
ax = sns.barplot(df['structure_quality'].value_counts(), palette='pastel')
ax.figure.set_size_inches(14, 6)
ax.set_xlabel('Qualidade da estrutura', fontsize=18)
ax.set_ylabel('')

plt.show()

# %%
colors = sns.color_palette('Oranges', n_colors=12)

ax = sns.barplot(df['month_sold'].value_counts(), palette=colors)
ax.figure.set_size_inches(14, 6)
ax.set_title('Quantidade de vendas de cada mes', fontsize=24, y=1.03)
ax.set_xlabel('Mes', fontsize=18)
ax.set_ylabel('Quantidade', fontsize=18)

plt.show()

# %% [markdown]
# ## Grafico de dispersão

# %%
x_plots = df.drop(columns='SALE_PRC').columns.to_list()

ax = sns.pairplot(data=df, y_vars='SALE_PRC', x_vars=x_plots, kind='reg')
ax.figure.set_size_inches(30, 3)

ax.tight_layout()
plt.show()
